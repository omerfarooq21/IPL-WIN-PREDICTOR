# %%
import numpy as np
import pandas as pd

# %%
matches = pd.read_csv('./archive/matches.csv')
div = pd.read_csv('./archive/deliveries.csv')

# %%
matches.head(3)
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
matches.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
v=matches.columns
len(v)
# Out:
# 18

# %%
matches.shape
# Out:
# (756, 18)

# %%
match = pd.read_csv('./8-24/matches.csv')

# %%
match.head(3)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
# 2       Rajasthan Royals             Rajasthan Royals           bat
#
#                   winner   result  result_margin  target_runs  target_overs  \
# ...

# %%
match.shape
# Out:
# (1095, 20)

# %%
v
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
p = match.columns

# %%
len(p)
# Out:
# 20

# %%
p
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
for i in p:
    if i in v:
        pass
    else:
        print(i)
# Out:
# season
# match_type
# result_margin
# target_runs
# target_overs
# super_over
# method

# %%
delvery = pd.read_csv('./8-24/deliveries.csv')

# %%
delvery.head(3)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN

# %%
delvery.shape
# Out:
# (260920, 17)

# %%
div.shape
# Out:
# (179078, 21)

# %%
delvery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
div.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delvery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
div.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
tot_score_df = delvery.groupby(['match_id', 'inning']).sum()['total_runs'].reset_index()

# %%
tot_score_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2212   1426310       2         174
# 2213   1426311       1         175
# 2214   1426311       2         139
# 2215   1426312       1         113
# 2216   1426312       2         114
#
# [2217 rows x 3 columns]

# %%
tot_score_df=tot_score_df[tot_score_df['inning'] == 1]

# %%
tot_score_df=tot_score_df.reset_index()

# %%
tot_score_df
# Out:
#       index  match_id  inning  total_runs
# 0         0    335982       1         222
# 1         2    335983       1         240
# 2         4    335984       1         129
# 3         6    335985       1         165
# 4         8    335986       1         110
# ...     ...       ...     ...         ...
# 1090   2207   1426307       1         214
# 1091   2209   1426309       1         159
# 1092   2211   1426310       1         172
# 1093   2213   1426311       1         175
# 1094   2215   1426312       1         113
#
# [1095 rows x 4 columns]

# %%
match
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
teams = ['Chennai Super Kings',
'Delhi Capitals',
'Gujarat Titans',
'Kolkata Knight Riders',
'Lucknow Super Giants',
'Mumbai Indians',
'Punjab Kings',
'Rajasthan Royals',
'Royal Challengers Bangalore',
'Sunrisers Hyderabad']

# %%
match['team1'] = match['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match['team2'] = match['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match['team1'] = match['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match['team2'] = match['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match['team1'] = match['team1'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')
match['team2'] = match['team2'].str.replace('Royal Challengers Bengaluru','Royal Challengers Bangalore')

match['team1'] = match['team1'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')
match['team2'] = match['team2'].str.replace('Rising Pune Supergiant','Lucknow Super Giants')

match['team1'] = match['team1'].str.replace('Rising Pune Supergiants','Lucknow Super Giants')
match['team2'] = match['team2'].str.replace('Rising Pune Supergiants','Lucknow Super Giants')

match['team1'] = match['team1'].str.replace('Pune Warriors','Lucknow Super Giants')
match['team2'] = match['team2'].str.replace('Pune Warriors','Lucknow Super Giants')

match['team1'] = match['team1'].str.replace( 'Gujarat Lions','Gujarat Titans')
match['team2'] = match['team2'].str.replace( 'Gujarat Lions','Gujarat Titans')

match['team1'] = match['team1'].str.replace( 'Kochi Tuskers Kerala','Gujarat Titans')
match['team2'] = match['team2'].str.replace( 'Kochi Tuskers Kerala','Gujarat Titans')


match['team1'] = match['team1'].str.replace( 'Kings XI Punjab','Punjab Kings')
match['team2'] = match['team2'].str.replace( 'Kings XI Punjab','Punjab Kings')

# %%
match = match[match['team1'].isin(teams)]
match = match[match['team2'].isin(teams)]

# %%
match.shape
# Out:
# (1081, 20)

# %%
match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
match['method'].isna().value_counts()
# Out:
# method
# True     1063
# False      18
# Name: count, dtype: int64

# %%
match['method'].isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1090    True
# 1091    True
# 1092    True
# 1093    True
# 1094    True
# Name: method, Length: 1081, dtype: bool

# %%
match = match[match['method'].isna()]

# %%
match
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
delvery
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
match.rename(columns={'id': 'match_id'}, inplace=True)

# %%
match
# Out:
#       match_id   season        city        date   match_type  player_of_match  \
# 0       335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1       335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2       335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3       335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4       335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...        ...      ...         ...         ...          ...              ...
# 1090   1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091   1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092   1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093   1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094   1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match=match[['match_id','city','winner','target_runs']]

# %%
match
# Out:
#       match_id        city                       winner  target_runs
# 0       335982   Bangalore        Kolkata Knight Riders        223.0
# 1       335983  Chandigarh          Chennai Super Kings        241.0
# 2       335984       Delhi             Delhi Daredevils        130.0
# 3       335985      Mumbai  Royal Challengers Bangalore        166.0
# 4       335986     Kolkata        Kolkata Knight Riders        111.0
# ...        ...         ...                          ...          ...
# 1090   1426307   Hyderabad          Sunrisers Hyderabad        215.0
# 1091   1426309   Ahmedabad        Kolkata Knight Riders        160.0
# 1092   1426310   Ahmedabad             Rajasthan Royals        173.0
# 1093   1426311     Chennai          Sunrisers Hyderabad        176.0
# 1094   1426312     Chennai        Kolkata Knight Riders        114.0
#
# [1063 rows x 4 columns]

# %%
delvery.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN

# %%
delivery_df = match.merge(delvery, on='match_id')

# %%
delivery_df = delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (123091, 20)

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'target_runs', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128    335982  Bangalore  Kolkata Knight Riders        223.0       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#        bowler non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# ...

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs'].cumsum()

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127    335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128    335982  Bangalore  Kolkata Knight Riders        223.0       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... non_striker batsman_runs  extra_runs  total_runs  extras_type  \
# ...

# %%
delivery_df['target_runs']=delivery_df['target_runs'].astype('Int64')

# %%
delivery_df['runs_left'] = delivery_df['target_runs']-delivery_df['current_score']

# %%
delivery_df.head(30)
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
# 129    335982  Bangalore  Kolkata Knight Riders          223       2
# 130    335982  Bangalore  Kolkata Knight Riders          223       2
# 131    335982  Bangalore  Kolkata Knight Riders          223       2
# 132    335982  Bangalore  Kolkata Knight Riders          223       2
# 133    335982  Bangalore  Kolkata Knight Riders          223       2
# 134    335982  Bangalore  Kolkata Knight Riders          223       2
# 135    335982  Bangalore  Kolkata Knight Riders          223       2
# 136    335982  Bangalore  Kolkata Knight Riders          223       2
# ...

# %%
delivery_df['balls_left'] = 120 - (delivery_df['over']*6 +delivery_df['ball'] )

# %%
delivery_df.head(25)
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
# 129    335982  Bangalore  Kolkata Knight Riders          223       2
# 130    335982  Bangalore  Kolkata Knight Riders          223       2
# 131    335982  Bangalore  Kolkata Knight Riders          223       2
# 132    335982  Bangalore  Kolkata Knight Riders          223       2
# 133    335982  Bangalore  Kolkata Knight Riders          223       2
# 134    335982  Bangalore  Kolkata Knight Riders          223       2
# 135    335982  Bangalore  Kolkata Knight Riders          223       2
# 136    335982  Bangalore  Kolkata Knight Riders          223       2
# ...

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna('0')
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x:x if x == '0' else '1' )
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int64')
wickets =  delivery_df.groupby('match_id')['player_dismissed'].cumsum().values
delivery_df['wickets'] = 10- wickets

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs extras_type  is_wicket  player_dismissed  dismissal_kind  \
# ...

# %%
delivery_df.tail(30)
# Out:
#         match_id     city                 winner  target_runs  inning  \
# 254580   1426312  Chennai  Kolkata Knight Riders          114       2
# 254581   1426312  Chennai  Kolkata Knight Riders          114       2
# 254582   1426312  Chennai  Kolkata Knight Riders          114       2
# 254583   1426312  Chennai  Kolkata Knight Riders          114       2
# 254584   1426312  Chennai  Kolkata Knight Riders          114       2
# 254585   1426312  Chennai  Kolkata Knight Riders          114       2
# 254586   1426312  Chennai  Kolkata Knight Riders          114       2
# 254587   1426312  Chennai  Kolkata Knight Riders          114       2
# 254588   1426312  Chennai  Kolkata Knight Riders          114       2
# 254589   1426312  Chennai  Kolkata Knight Riders          114       2
# 254590   1426312  Chennai  Kolkata Knight Riders          114       2
# 254591   1426312  Chennai  Kolkata Knight Riders          114       2
# ...

# %%
delivery_df['CRR'] = delivery_df['current_score']*6/(120 - delivery_df['balls_left'])

# %%
delivery_df.head(45)
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
# 129    335982  Bangalore  Kolkata Knight Riders          223       2
# 130    335982  Bangalore  Kolkata Knight Riders          223       2
# 131    335982  Bangalore  Kolkata Knight Riders          223       2
# 132    335982  Bangalore  Kolkata Knight Riders          223       2
# 133    335982  Bangalore  Kolkata Knight Riders          223       2
# 134    335982  Bangalore  Kolkata Knight Riders          223       2
# 135    335982  Bangalore  Kolkata Knight Riders          223       2
# 136    335982  Bangalore  Kolkata Knight Riders          223       2
# ...

# %%
delivery_df['RRR'] = (delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... is_wicket player_dismissed  dismissal_kind  fielder  current_score  \
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result ,axis=1)

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  target_runs  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders          223       2
# 125    335982  Bangalore  Kolkata Knight Riders          223       2
# 126    335982  Bangalore  Kolkata Knight Riders          223       2
# 127    335982  Bangalore  Kolkata Knight Riders          223       2
# 128    335982  Bangalore  Kolkata Knight Riders          223       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... player_dismissed dismissal_kind  fielder  current_score  runs_left  \
# ...

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'target_runs', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder', 'current_score',
#        'runs_left', 'balls_left', 'wickets', 'CRR', 'RRR', 'result'],
#       dtype='object')

# %%
final_df = delivery_df[['batting_team','bowling_team','runs_left','balls_left', 'wickets' , 'target_runs', 'CRR', 'RRR',
       'result']]

# %%
final_df=final_df.reset_index(drop='index')

# %%
final_df
# Out:
#                        batting_team           bowling_team  runs_left  \
# 0       Royal Challengers Bangalore  Kolkata Knight Riders        222
# 1       Royal Challengers Bangalore  Kolkata Knight Riders        221
# 2       Royal Challengers Bangalore  Kolkata Knight Riders        221
# 3       Royal Challengers Bangalore  Kolkata Knight Riders        220
# 4       Royal Challengers Bangalore  Kolkata Knight Riders        219
# ...                             ...                    ...        ...
# 123086        Kolkata Knight Riders    Sunrisers Hyderabad          4
# 123087        Kolkata Knight Riders    Sunrisers Hyderabad          3
# 123088        Kolkata Knight Riders    Sunrisers Hyderabad          2
# 123089        Kolkata Knight Riders    Sunrisers Hyderabad          1
# 123090        Kolkata Knight Riders    Sunrisers Hyderabad          0
#
#         balls_left  wickets  target_runs        CRR        RRR  result
# ...

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample()
# Out:
#          batting_team   bowling_team  runs_left  balls_left  wickets  \
# 65267  Mumbai Indians  Gujarat Lions        121          84        9
#
#        target_runs       CRR       RRR  result
# 65267          177  9.333333  8.642857       1

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left']!=0]

# %%
x = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=1)

# %%
x_train
# Out:
#                batting_team                 bowling_team  runs_left  \
# 111886       Gujarat Titans             Rajasthan Royals        119
# 39483      Delhi Daredevils               Mumbai Indians         82
# 25365      Rajasthan Royals          Chennai Super Kings         78
# 2778        Kings XI Punjab  Royal Challengers Bangalore         64
# 91096   Sunrisers Hyderabad        Kolkata Knight Riders        154
# ...                     ...                          ...        ...
# 102177  Chennai Super Kings                 Punjab Kings        104
# 23046   Chennai Super Kings                Pune Warriors         31
# 88893      Rajasthan Royals               Mumbai Indians        171
# 5017        Kings XI Punjab              Deccan Chargers         48
# 77919        Delhi Capitals        Kolkata Knight Riders        142
#
#         balls_left  wickets  target_runs       CRR        RRR
# 111886         119       10          119  0.000000        6.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer(
    [
        ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team'])
    ],
    remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# /Users/omerfarooq/Desktop/dsp/venv/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
x_train.describe()
# Out:
#        runs_left    balls_left       wickets  target_runs           CRR  \
# count    98128.0  98128.000000  98128.000000      98128.0  98128.000000
# mean   94.483736     62.755564      7.507327   168.837355      7.572316
# std    50.802129     33.329843      2.154528     30.64508      2.332933
# min         -5.0     -3.000000      0.000000         63.0      0.000000
# 25%         54.0     35.000000      6.000000        149.0      6.367347
# 50%         93.0     64.000000      8.000000        168.0      7.588235
# 75%        132.0     92.000000      9.000000        188.0      8.842105
# max        287.0    119.000000     10.000000        288.0     36.000000
#
#              RRR
# count    98128.0
# mean   10.753139
# std    14.558694
# min       -468.0
# 25%     7.297297
# 50%     9.056604
# 75%        11.25
# max        792.0

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7973749643337545

# %%
pipe.predict_proba(x_test)[10]
# Out:
# array([0.08407495, 0.91592505])

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders          223       2
# 125       335982  Bangalore  Kolkata Knight Riders          223       2
# 126       335982  Bangalore  Kolkata Knight Riders          223       2
# 127       335982  Bangalore  Kolkata Knight Riders          223       2
# 128       335982  Bangalore  Kolkata Knight Riders          223       2
# ...          ...        ...                    ...          ...     ...
# 254605   1426312    Chennai  Kolkata Knight Riders          114       2
# 254606   1426312    Chennai  Kolkata Knight Riders          114       2
# 254607   1426312    Chennai  Kolkata Knight Riders          114       2
# 254608   1426312    Chennai  Kolkata Knight Riders          114       2
# 254609   1426312    Chennai  Kolkata Knight Riders          114       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df[(delivery_df['ball'] == 6)]
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 129       335982  Bangalore  Kolkata Knight Riders          223       2
# 136       335982  Bangalore  Kolkata Knight Riders          223       2
# 142       335982  Bangalore  Kolkata Knight Riders          223       2
# 149       335982  Bangalore  Kolkata Knight Riders          223       2
# 155       335982  Bangalore  Kolkata Knight Riders          223       2
# ...          ...        ...                    ...          ...     ...
# 254582   1426312    Chennai  Kolkata Knight Riders          114       2
# 254588   1426312    Chennai  Kolkata Knight Riders          114       2
# 254594   1426312    Chennai  Kolkata Knight Riders          114       2
# 254600   1426312    Chennai  Kolkata Knight Riders          114       2
# 254606   1426312    Chennai  Kolkata Knight Riders          114       2
#
#                        batting_team           bowling_team  over  ball  \
# ...

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','runs_left','balls_left', 'wickets' , 'target_runs', 'CRR', 'RRR']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['target_runs'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:] - np.array(new_runs)
    wickets = list(temp_df['wickets'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
delivery_df[delivery_df['match_id'] == 335984].tail(10)
# Out:
#      match_id   city            winner  target_runs  inning      batting_team  \
# 682    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 683    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 684    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 685    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 686    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 687    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 688    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 689    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 690    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
# 691    335984  Delhi  Delhi Daredevils          130       2  Delhi Daredevils
#
#          bowling_team  over  ball     batter  ... player_dismissed  \
# ...

# %%
temp_df,target = match_progression(delivery_df,335984,pipe)
temp_df
# Out:
# Target- 130
#      end_of_over  runs_after_over  wickets_in_over  lose   win
# 600            1                8                0  12.9  87.1
# 606            2               13                1  13.5  86.5
# 613            3                5                0  14.4  85.6
# 619            4               10                0  11.0  89.0
# 625            5               12                0   7.4  92.6
# 631            6                7                0   6.8  93.2
# 638            7                4                0   7.4  92.6
# 644            8               12                0   4.9  95.1
# 651            9                7                0   4.5  95.5
# 657           10                7                0   4.0  96.0
# 664           11               10                0   3.0  97.0
# 670           12                5                0   3.0  97.0
# 676           13               10                0   2.2  97.8
# 683           14                5                0   2.2  97.8
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Text(0.5, 1.0, 'Target-130')

# %%
import pickle
pickle.dump(pipe,open('ipl.pkl','wb'))
